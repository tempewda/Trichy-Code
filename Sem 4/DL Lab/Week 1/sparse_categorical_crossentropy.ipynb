# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
(xtrain, ytrain), (xtest, ytest) = keras.datasets.mnist.load_data()

# %%
xtrain = xtrain.reshape(-1, 28 * 28).astype("float32")/255.0

# %%
xtest = xtest.reshape(-1, 28 * 28).astype("float32")/255.0

# %%
numclass = 10

# %%
def MLPjourney(deep = False):
    model = keras.Sequential()
    model.add(layers.Input(shape = (784,)))
    if deep:
        model.add(layers.Dense(512, activation = "relu"))
        model.add(layers.Dense(256, activation = "relu"))
        model.add(layers.Dense(128, activation = "relu"))
    else:
        model.add(layers.Dense(512, activation = "relu"))
    model.add(layers.Dense(numclass, activation = "softmax"))
    model.compile(
        optimizer = keras.optimizers.Adam(1e-3),
        loss = "sparse_categorical_crossentropy",
        metrics = ["Accuracy"]
    )

    return model

# %%
shallow = MLPjourney(deep = False)

# %%
shallow.fit(xtrain, ytrain, epochs = 10, batch_size = 64, validation_split = 0.2)
# Out:
# Epoch 1/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - Accuracy: 0.8706 - loss: 0.4391 - val_Accuracy: 0.9561 - val_loss: 0.1466
# Epoch 2/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9683 - loss: 0.1090 - val_Accuracy: 0.9708 - val_loss: 0.0967
# Epoch 3/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9799 - loss: 0.0668 - val_Accuracy: 0.9744 - val_loss: 0.0843
# Epoch 4/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9878 - loss: 0.0446 - val_Accuracy: 0.9763 - val_loss: 0.0823
# Epoch 5/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9917 - loss: 0.0280 - val_Accuracy: 0.9754 - val_loss: 0.0851
# Epoch 6/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9939 - loss: 0.0222 - val_Accuracy: 0.9788 - val_loss: 0.0783
# Epoch 7/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9963 - loss: 0.0143 - val_Accuracy: 0.9727 - val_loss: 0.1014
# Epoch 8/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9972 - loss: 0.0111 - val_Accuracy: 0.9752 - val_loss: 0.0933
# Epoch 9/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9978 - loss: 0.0097 - val_Accuracy: 0.9767 - val_loss: 0.0955
# Epoch 10/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9979 - loss: 0.0078 - val_Accuracy: 0.9751 - val_loss: 0.1012

# %%
testloss, testacc = shallow.evaluate(xtest, ytest, verbose = 1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9739 - loss: 0.1000

# %%
deep = MLPjourney(deep = True)

# %%
deep.fit(xtrain, ytrain, epochs = 10, batch_size = 64, validation_split = 0.2)
# Out:
# Epoch 1/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - Accuracy: 0.8764 - loss: 0.4188 - val_Accuracy: 0.9640 - val_loss: 0.1171
# Epoch 2/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - Accuracy: 0.9705 - loss: 0.0935 - val_Accuracy: 0.9684 - val_loss: 0.1008
# Epoch 3/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9819 - loss: 0.0580 - val_Accuracy: 0.9700 - val_loss: 0.1005
# Epoch 4/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9862 - loss: 0.0424 - val_Accuracy: 0.9748 - val_loss: 0.0950
# Epoch 5/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9894 - loss: 0.0318 - val_Accuracy: 0.9747 - val_loss: 0.0915
# Epoch 6/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9913 - loss: 0.0268 - val_Accuracy: 0.9758 - val_loss: 0.0963
# Epoch 7/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9922 - loss: 0.0246 - val_Accuracy: 0.9768 - val_loss: 0.0967
# Epoch 8/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9934 - loss: 0.0205 - val_Accuracy: 0.9772 - val_loss: 0.0981
# Epoch 9/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9944 - loss: 0.0178 - val_Accuracy: 0.9774 - val_loss: 0.1012
# Epoch 10/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9950 - loss: 0.0154 - val_Accuracy: 0.9753 - val_loss: 0.1038

# %%
testloss, testacc = deep.evaluate(xtest, ytest, verbose = 1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9725 - loss: 0.1092

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
(xtrain, ytrain), (xtest, ytest) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
xtrain = xtrain.reshape(-1, 28 * 28).astype("float32")/255.0

# %%
xtest = xtest.reshape(-1, 28 * 28).astype("float32")/255.0

# %%
numclass = 10

# %%
def MLPjourney(deep = False):
    model = keras.Sequential()
    model.add(layers.Input(shape = (784,)))
    if deep:
        model.add(layers.Dense(512, activation = "relu"))
        model.add(layers.Dense(256, activation = "relu"))
        model.add(layers.Dense(128, activation = "relu"))
    else:
        model.add(layers.Dense(512, activation = "relu"))
    model.add(layers.Dense(numclass, activation = "softmax"))
    model.compile(
        optimizer = keras.optimizers.Adam(1e-3),
        loss = "crossentropy",
        metrics = ["Accuracy"]
    )

    return model

# %%
shallow = MLPjourney(deep = False)

# %%
shallow.fit(xtrain, ytrain, epochs = 10, batch_size = 64, validation_split = 0.2)
# Out:
# Epoch 1/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - Accuracy: 0.8758 - loss: 0.4309 - val_Accuracy: 0.9607 - val_loss: 0.1314
# Epoch 2/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - Accuracy: 0.9686 - loss: 0.1104 - val_Accuracy: 0.9711 - val_loss: 0.0989
# Epoch 3/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9802 - loss: 0.0647 - val_Accuracy: 0.9709 - val_loss: 0.0883
# Epoch 4/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9870 - loss: 0.0439 - val_Accuracy: 0.9755 - val_loss: 0.0814
# Epoch 5/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9908 - loss: 0.0316 - val_Accuracy: 0.9754 - val_loss: 0.0812
# Epoch 6/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9955 - loss: 0.0192 - val_Accuracy: 0.9758 - val_loss: 0.0835
# Epoch 7/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9960 - loss: 0.0150 - val_Accuracy: 0.9730 - val_loss: 0.0931
# Epoch 8/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9964 - loss: 0.0130 - val_Accuracy: 0.9766 - val_loss: 0.0927
# Epoch 9/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - Accuracy: 0.9973 - loss: 0.0103 - val_Accuracy: 0.9763 - val_loss: 0.0955
# Epoch 10/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - Accuracy: 0.9964 - loss: 0.0113 - val_Accuracy: 0.9750 - val_loss: 0.0957

# %%
testloss, testacc = shallow.evaluate(xtest, ytest, verbose = 1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9743 - loss: 0.0991

# %%
deep = MLPjourney(deep = True)

# %%
deep.fit(xtrain, ytrain, epochs = 10, batch_size = 64, validation_split = 0.2)
# Out:
# Epoch 1/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - Accuracy: 0.8770 - loss: 0.4051 - val_Accuracy: 0.9618 - val_loss: 0.1262
# Epoch 2/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9724 - loss: 0.0889 - val_Accuracy: 0.9738 - val_loss: 0.0906
# Epoch 3/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9803 - loss: 0.0627 - val_Accuracy: 0.9728 - val_loss: 0.0952
# Epoch 4/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9869 - loss: 0.0408 - val_Accuracy: 0.9704 - val_loss: 0.1052
# Epoch 5/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9894 - loss: 0.0325 - val_Accuracy: 0.9699 - val_loss: 0.1049
# Epoch 6/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9917 - loss: 0.0265 - val_Accuracy: 0.9759 - val_loss: 0.0949
# Epoch 7/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9934 - loss: 0.0227 - val_Accuracy: 0.9742 - val_loss: 0.1082
# Epoch 8/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9927 - loss: 0.0215 - val_Accuracy: 0.9739 - val_loss: 0.1032
# Epoch 9/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9936 - loss: 0.0186 - val_Accuracy: 0.9764 - val_loss: 0.0988
# Epoch 10/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - Accuracy: 0.9945 - loss: 0.0176 - val_Accuracy: 0.9796 - val_loss: 0.0961

# %%
testloss, testacc = deep.evaluate(xtest, ytest, verbose = 1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Accuracy: 0.9784 - loss: 0.0932
